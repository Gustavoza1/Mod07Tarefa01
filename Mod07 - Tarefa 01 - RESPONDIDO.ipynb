# %% [markdown]
# # Módulo 07, Tarefa 01
#
# Vamos começar a mexer na nossa base de projeto? Já fizemos um exercício de montar a variável resposta, já pudemos perceber que essa atividade pode não ser trivial. Vamos agora trabalhar a base para que fique propícia ao *scikitlearn* para trabalharmos.
#
# Lembrando, a base se chama demo01.csv, e originalmente está publicada [aqui](https://www.kaggle.com/rikdifos/credit-card-approval-prediction).

# %% [markdown]
# #### 1) Carregue a base e avalie:
#
# - As variáveis
# - Tipos de dados de cada variável
# - Quantidade de missings
# - Distribuição da variável resposta (mau)

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
base = pd.read_csv('demo01.csv')
base.head()
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
#        idade  tempo_emprego  possui_celular  possui_fone_comercial  \
# ...

# %%
#tipos de dados de cada variavel
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sexo                   16650 non-null  object
#  1   posse_de_veiculo       16650 non-null  object
#  2   posse_de_imovel        16650 non-null  object
#  3   qtd_filhos             16650 non-null  int64
#  4   tipo_renda             16650 non-null  object
#  5   educacao               16650 non-null  object
#  6   estado_civil           16650 non-null  object
#  7   tipo_residencia        16650 non-null  object
#  8   idade                  16650 non-null  float64
#  9   tempo_emprego          16650 non-null  float64
#  10  possui_celular         16650 non-null  int64
#  11  possui_fone_comercial  16650 non-null  int64
#  12  possui_fone            16650 non-null  int64
#  13  possui_email           16650 non-null  int64
# ...

# %%
#Quantidade de missings
base.isna().sum()
# Out:
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# possui_celular           0
# possui_fone_comercial    0
# possui_fone              0
# possui_email             0
# qt_pessoas_residencia    0
# mau                      0
# dtype: int64

# %%
#Distribuição da variável resposta (mau)
base['mau'].value_counts()
# Out:
# mau
# False    16260
# True       390
# Name: count, dtype: int64

# %%
#distribuicao em %

mau_perc = base['mau'].value_counts(normalize=True) * 100
mau_perc
# Out:
# mau
# False    97.657658
# True      2.342342
# Name: proportion, dtype: float64

# %% [markdown]
# #### 2) Vamos montar um metadados
#
# 1. Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
# 2. Adicione uma coluna nesse *dataframe* chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável.
#     Dica:
#         1. inicie uma lista vazia
#         2. faça um for ao longo dos nomes das variáveis,
#         3. conte o número de categorias dessa variável
#         4. acumule essa informação de 3. na lista que você criou em 1.
#         5. No final, essa lista pode ser atribuída à nossa variável.
# 3. Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

# %%
# 1) Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
dfmeta = pd.DataFrame(base.dtypes)
dfmeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, sexo to mau
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       16 non-null     object
# dtypes: object(1)
# memory usage: 812.0+ bytes

# %%
# 2) Adicione uma coluna nesse dataframe chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável. Dica: 1. inicie uma lista vazia 2. faça um for ao longo dos nomes das variáveis

#!dfmeta['qtd_categorias'] = []

dfmeta['qtd_categorias'] = base.apply(lambda x: x.nunique())

dfmeta
# Out:
#                              0  qtd_categorias
# sexo                    object               2
# posse_de_veiculo        object               2
# posse_de_imovel         object               2
# qtd_filhos               int64               8
# tipo_renda              object               5
# educacao                object               5
# estado_civil            object               5
# tipo_residencia         object               6
# idade                  float64            5298
# tempo_emprego          float64            3005
# possui_celular           int64               1
# possui_fone_comercial    int64               2
# possui_fone              int64               2
# possui_email             int64               2
# qt_pessoas_residencia  float64               9
# mau                       bool               2

# %%
# 3) - Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

#base['tipo_renda'].value_counts() # Working = 1
#base['educacao'].value_counts() # Secondary / secondary special = 1
#base['estado_civil'].value_counts() # Married = 1
#base['tipo_residencia'].value_counts() # House / apartment = 1

base_dummie = pd.get_dummies(base, columns = ['tipo_renda', 'educacao', 'estado_civil', 'tipo_residencia'], drop_first = True)
base_dummie
# Out:
#       sexo posse_de_veiculo posse_de_imovel  qtd_filhos      idade  \
# 0        M                Y               Y           0  58.832877
# 1        F                N               Y           0  52.356164
# 2        F                N               Y           0  52.356164
# 3        M                Y               Y           0  46.224658
# 4        F                Y               N           0  29.230137
# ...    ...              ...             ...         ...        ...
# 16645    F                N               Y           0  54.109589
# 16646    F                N               Y           0  43.389041
# 16647    M                Y               Y           0  30.005479
# 16648    M                Y               Y           0  30.005479
# 16649    F                N               Y           0  33.936986
#
#        tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# 0           3.106849               1                      0            0
# ...

# %% [markdown]
# #### 3) Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}. Crie um *dataframe* apenas com as variáveis apropriadas para entrada no scikitlearn - elimine as variáveis tipo *str*, mantendo apenas suas versões *dummy*.

# %%
base_dummie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 29 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   sexo                                    16650 non-null  object
#  1   posse_de_veiculo                        16650 non-null  object
#  2   posse_de_imovel                         16650 non-null  object
#  3   qtd_filhos                              16650 non-null  int64
#  4   idade                                   16650 non-null  float64
#  5   tempo_emprego                           16650 non-null  float64
#  6   possui_celular                          16650 non-null  int64
#  7   possui_fone_comercial                   16650 non-null  int64
#  8   possui_fone                             16650 non-null  int64
#  9   possui_email                            16650 non-null  int64
# ...

# %%
base_dummie.head()
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos      idade  tempo_emprego  \
# 0    M                Y               Y           0  58.832877       3.106849
# 1    F                N               Y           0  52.356164       8.358904
# 2    F                N               Y           0  52.356164       8.358904
# 3    M                Y               Y           0  46.224658       2.106849
# 4    F                Y               N           0  29.230137       3.021918
#
#    possui_celular  possui_fone_comercial  possui_fone  possui_email  ...  \
# 0               1                      0            0             0  ...
# 1               1                      0            1             1  ...
# 2               1                      0            1             1  ...
# 3               1                      1            1             1  ...
# 4               1                      0            0             0  ...
#
# ...

# %%
base_dummie.sexo = base_dummie.sexo.map({'F': 1, 'M': 0})
base_dummie.posse_de_veiculo = base_dummie.posse_de_veiculo.map({'Y': 1, 'N': 0})
base_dummie.posse_de_imovel = base_dummie.posse_de_imovel.map({'Y': 1, 'N': 0})

#alterando valor de mau para 1 ou 0 para proximo exercicio
base_dummie.mau = base_dummie.mau.astype(int)

base_dummie.head()
# Out:
#    sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos      idade  \
# 0     0                 1                1           0  58.832877
# 1     1                 0                1           0  52.356164
# 2     1                 0                1           0  52.356164
# 3     0                 1                1           0  46.224658
# 4     1                 1                0           0  29.230137
#
#    tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# 0       3.106849               1                      0            0
# 1       8.358904               1                      0            1
# 2       8.358904               1                      0            1
# 3       2.106849               1                      1            1
# 4       3.021918               1                      0            0
#
#    possui_email  ...  educacao_Secondary / secondary special  \
# 0             0  ...                                    True
# ...

# %%
base_dummie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 29 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   sexo                                    16650 non-null  int64
#  1   posse_de_veiculo                        16650 non-null  int64
#  2   posse_de_imovel                         16650 non-null  int64
#  3   qtd_filhos                              16650 non-null  int64
#  4   idade                                   16650 non-null  float64
#  5   tempo_emprego                           16650 non-null  float64
#  6   possui_celular                          16650 non-null  int64
#  7   possui_fone_comercial                   16650 non-null  int64
#  8   possui_fone                             16650 non-null  int64
#  9   possui_email                            16650 non-null  int64
# ...

# %% [markdown]
# #### 4) Qual variável é mais poderosa?
#
# Considere as variáveis ```possui_email``` e ```posse_de_veiculo```. Faça uma tabela cruzada entre elas e responda qual delas te parece mais poderosa para prever a probabilidade de ```mau = 1```?

# %%
base_dummie[['mau', 'posse_de_veiculo', 'possui_email']].groupby(['mau']).count()
# Out:
#      posse_de_veiculo  possui_email
# mau
# 0               16260         16260
# 1                 390           390

# %%
base_dummie[['mau', 'posse_de_veiculo', 'possui_email']].groupby(['mau', 'possui_email']).count()
# Out:
#                   posse_de_veiculo
# mau possui_email
# 0   0                        14810
#     1                         1450
# 1   0                          360
#     1                           30

# %%
base_dummie[['mau', 'posse_de_veiculo', 'possui_email']].groupby(['mau', 'posse_de_veiculo']).count()
# Out:
#                       possui_email
# mau posse_de_veiculo
# 0   0                         9931
#     1                         6329
# 1   0                          247
#     1                          143

# %%
perc_veiculo = base_dummie.loc[base_dummie['mau'] == 1, 'posse_de_veiculo'].value_counts(normalize=True) * 100
perc_veiculo
# Out:
# posse_de_veiculo
# 0    63.333333
# 1    36.666667
# Name: proportion, dtype: float64

# %%
perc_email = base_dummie.loc[base_dummie['mau'] == 1, 'possui_email'].value_counts(normalize=True) * 100
perc_email
# Out:
# possui_email
# 0    92.307692
# 1     7.692308
# Name: proportion, dtype: float64

# %% [markdown]
# A variavável **posse_de_veiculo** tem maior probabilidade de prever a variável **mau**, com cerca de **37% = 1**

# %% [markdown]
# #### 5) Salve a base, pois ela será utilizada no final deste módulo.

# %%
base_dummie.to_csv('Mod07_Aula1_Tratado.csv')
